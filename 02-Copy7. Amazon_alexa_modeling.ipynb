# %%
import json
import pandas as pd
import itertools
import csv
import string
import pickle
import matplotlib.pyplot as plt

from collections import Counter
import re
import spacy
import nltk
from spacy.lang.en import English
from nltk.util import ngrams
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import gensim
from gensim import corpora
from gensim.models.ldamodel import LdaModel
nltk.download('wordnet')
nltk.download('stopwords')

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF, TruncatedSVD
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score
# Out:
# [nltk_data] Downloading package wordnet to /Users/xzhou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/xzhou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
plt.style.use('seaborn')

# %%
pkl_path = '/Users/xzhou/github/project_files/amazon/amazon_alexa_reviews.pkl'

with open(pkl_path, 'rb') as pkl_file:
    df = pd.read_pickle(pkl_file)

df.head()
# Out:
#    rating       date                                             review  \
# 2       4 2018-07-31  Sometimes while playing a game, you can answer...
# 3       5 2018-07-31  I have had a lot of fun with this thing. My 4 ...
# 5       5 2018-07-31  I received the echo as a gift. I needed anothe...
# 6       3 2018-07-31  Without having a cellphone, I cannot use many ...
# 7       5 2018-07-31  I think this is the 5th one I've purchased. I'...
#
#                                       review_by_word  word_count
# 2  [Sometimes, while, playing, a, game, ,, you, c...          41
# 3  [I, have, had, a, lot, of, fun, with, this, th...          38
# 5  [I, received, the, echo, as, a, gift, ., I, ne...          38
# 6  [Without, having, a, cellphone, ,, I, can, not...          84
# 7  [I, think, this, is, the, 5th, one, I, 've, pu...          45

# %%
df.shape
# Out:
# (7248, 5)

# %%
# Assign sentiment:
# 1 represents positive sentiment, 0 represents neutral, 
# and -1 represents negative sentiment

def assign_sentiment(x):
    sentiment = ''
    if x < 3:
        sentiment = -1
    elif x == 3:
        sentiment = 0
    else:
        sentiment =1
    return sentiment

# %%
df['sentiment'] = df['rating'].apply(lambda x: assign_sentiment(x))

# %%
# Slice data based on sentiment

df_positive = df[df['sentiment']==1]
df_neutral = df[df['sentiment']==0]
df_negative = df[df['sentiment']==-1]

# %%
X = df['review']
X_positive = df_positive['review']
X_neutral = df_neutral['review']
X_negative = df_negative['review']

# %%
class KMeansEngine:
    def __init__(self, data, vectorizer_name, max_df_, min_df_, vector_max_features_):
        """
        The function supports tfidf and count vecotrizer only. Please select 'tiidf' or 'count'
        for vecotrizer. Provided with desired arguments, it will create a vector, 
        and vectorize data
        """
        self.vector_max_features = vector_max_features_
        self.vectorizer(vectorizer_name, max_df_, min_df_)
        self.vectorize_data(data)
            
    
    def vectorizer(self, vectorizer_name, max_df_, min_df_):
        """
        The function supports tfidf and count vecotrizer only. Provided with desired
        argument, return a vector
        """
        if vectorizer_name.lower() == 'tfidf':
            self.vector = TfidfVectorizer(ngram_range=(1,2),
                               stop_words='english',
                               token_pattern="\\b[a-z][a-z]+\\b",
                               lowercase=True,
                               max_df=max_df_,
                               min_df=min_df_,
                               max_features=self.vector_max_features)
            return self.vector
        
        elif vectorizer_name.lower() == 'count':
            self.vector = CountVectorizer(ngram_range=(1,2),
                               stop_words='english',
                               token_pattern="\\b[a-z][a-z]+\\b",
                               lowercase=True,
                               max_df=max_df_,
                               min_df=min_df_,
                               max_features=self.vector_max_features)
            return self.vector
        
        else:
            return 'error'
        
    
    def vectorize_data(self, data):
        """
        Return vectorized data using specificed vector
        """
        self.vectorized_data = self.vector.fit_transform(data)       
        return self.vectorized_data
    
    def dimension_reduction (self, reduction_method, reduction_max_features_):
        """
        Support svd and nmf only.
        """
        if reduction_method.lower() == 'svd':
            lsa = TruncatedSVD(n_components=reduction_max_features_)
            self.reduced_data = lsa.fit_transform(self.vectorized_data)
            
        elif reduction_method.lower() == 'nmf':
            nmf = NMF(n_components=reduction_max_features_)
            self.reduced_data = nmf.fit_transform(self.vectorized_data)
            
        return self.reduced_data
            
    
    def KMeans_iterations(self, max_num_clusters):
        """
        Perform Kmeans fit from 2 to maximum number of clusters specified,
        return sil score and SSE for each number of cluster 
        """
        self.Sil_coefs = []
        self.SSEs = []
        self.k_clusters = range(2, max_num_clusters+1)

        for k in range(2, max_num_clusters+1):
            km = KMeans(n_clusters=k, random_state=99, n_jobs=-1)
            km.fit(self.reduced_data)
            labels = km.labels_
            self.Sil_coefs.append(silhouette_score(self.reduced_data, labels, metric='euclidean'))
            self.SSEs.append(km.inertia_) 
  
            
    def draw_KMeans_plot(self):
        """
        Plot two subplots for Sil_coefficients, and SSEs
        """

        fig, ax = plt.subplots(1,2, figsize=(15,5), sharex=True, dpi=200)

        ax[0].plot(self.k_clusters, self.Sil_coefs)
        ax[0].set_xlabel('number of clusters')
        ax[0].set_ylabel('Silhouette coefficient')

        ax[1].plot(self.k_clusters, self.SSEs)
        ax[1].set_xlabel('number of clusters')
        ax[1].set_ylabel('SSE')
        
    def KMeans_model(self, num_clusters):
        """
        This is to build one KMeans model with given argument
        """
        km = KMeans(n_clusters=num_clusters, random_state=99, n_jobs=-1)
        km.fit(self.reduced_data)
        labels = km.labels_
        
        self.optimized_model=km
        return km

# %%
# min_df=0.002, max_feature =25

# Case 1: 'tfidf', 'svd', min_df=0.002, reduced_features=25
lsa_tfidf_0002_25 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_tfidf_0002_25.dimension_reduction('svd', reduction_max_features_=25)
lsa_tfidf_0002_25.KMeans_iterations(10)


# Case 2: 'count', 'svd', min_df=0.002, reduced_features=25
lsa_cv_0002_25 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_cv_0002_25.dimension_reduction('svd', reduction_max_features_=25)
lsa_cv_0002_25.KMeans_iterations(10)


# Case 3: 'count', 'nmf', min_df=0.002, reduced_features=25
nmf_cv_0002_25 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
nmf_cv_0002_25.dimension_reduction('nmf', reduction_max_features_=25)
nmf_cv_0002_25.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0002_25.draw_KMeans_plot()
lsa_cv_0002_25.draw_KMeans_plot()
nmf_cv_0002_25.draw_KMeans_plot()

# %%
# min_df=0.002, max_feature =50

# Case 4: 'tfidf', 'svd', min_df=0.002, reduced_features=50
lsa_tfidf_0002_50 = KMeansEngine(X_negative, 'tfidf', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_tfidf_0002_50.dimension_reduction('svd', reduction_max_features_=50)
lsa_tfidf_0002_50.KMeans_iterations(10)


# Case 5: 'count', 'svd', min_df=0.002, reduced_features=50
lsa_cv_0002_50 = KMeansEngine(X_negative, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_cv_0002_50.dimension_reduction('svd', reduction_max_features_=50)
lsa_cv_0002_50.KMeans_iterations(10)


# Case 6: 'count', 'nmf', min_df=0.002, reduced_features=50
nmf_cv_0002_50 = KMeansEngine(X_negative, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
nmf_cv_0002_50.dimension_reduction('nmf', reduction_max_features_=50)
nmf_cv_0002_50.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0002_50.draw_KMeans_plot()
lsa_cv_0002_50.draw_KMeans_plot()
nmf_cv_0002_50.draw_KMeans_plot()

# %%
# min_df=0.002, max_feature =100

# Case 7: 'tfidf', 'svd', min_df=0.002, reduced_features=100
lsa_tfidf_0002_100 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_tfidf_0002_100.dimension_reduction('svd', reduction_max_features_=100)
lsa_tfidf_0002_100.KMeans_iterations(10)


# Case 8: 'count', 'svd', min_df=0.002, reduced_features=100
lsa_cv_0002_100 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_cv_0002_100.dimension_reduction('svd', reduction_max_features_=100)
lsa_cv_0002_100.KMeans_iterations(10)


# Case 9: 'count', 'nmf', min_df=0.002, reduced_features=100
nmf_cv_0002_100 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
nmf_cv_0002_100.dimension_reduction('nmf', reduction_max_features_=100)
nmf_cv_0002_100.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0002_100.draw_KMeans_plot()
lsa_cv_0002_100.draw_KMeans_plot()
nmf_cv_0002_100.draw_KMeans_plot()

# %%
# min_df=0.002, max_feature =200

# Case 10: 'tfidf', 'svd', min_df=0.002, reduced_features=200
lsa_tfidf_0002_200 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_tfidf_0002_200.dimension_reduction('svd', reduction_max_features_=200)
lsa_tfidf_0002_200.KMeans_iterations(10)


# Case 11: 'count', 'svd', min_df=0.002, reduced_features=200
lsa_cv_0002_200 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
lsa_cv_0002_200.dimension_reduction('svd', reduction_max_features_=200)
lsa_cv_0002_200.KMeans_iterations(10)


# Case 12: 'count', 'nmf', min_df=0.002, reduced_features=200
nmf_cv_0002_200 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.002, vector_max_features_=2000)
nmf_cv_0002_200.dimension_reduction('nmf', reduction_max_features_=200)
nmf_cv_0002_200.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0002_200.draw_KMeans_plot()
lsa_cv_0002_200.draw_KMeans_plot()
nmf_cv_0002_200.draw_KMeans_plot()

# %%
# min_df=0.005, max_feature =25

# Case 13: 'tfidf', 'svd', min_df=0.005, reduced_features=25
lsa_tfidf_0005_25 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_tfidf_0005_25.dimension_reduction('svd', reduction_max_features_=25)
lsa_tfidf_0005_25.KMeans_iterations(10)


# Case 14: 'count', 'svd', min_df=0.005, reduced_features=25
lsa_cv_0005_25 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_cv_0005_25.dimension_reduction('svd', reduction_max_features_=25)
lsa_cv_0005_25.KMeans_iterations(10)


# Case 15: 'count', 'nmf', min_df=0.005, reduced_features=25
nmf_cv_0005_25 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
nmf_cv_0005_25.dimension_reduction('nmf', reduction_max_features_=25)
nmf_cv_0005_25.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0005_25.draw_KMeans_plot()
lsa_cv_0005_25.draw_KMeans_plot()
nmf_cv_0005_25.draw_KMeans_plot()

# %%
# min_df=0.005, max_feature =50

# Case 16: 'tfidf', 'svd', min_df=0.005, reduced_features=50
lsa_tfidf_0005_50 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_tfidf_0005_50.dimension_reduction('svd', reduction_max_features_=50)
lsa_tfidf_0005_50.KMeans_iterations(10)


# Case 17: 'count', 'svd', min_df=0.005, reduced_features=50
lsa_cv_0005_50 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_cv_0005_50.dimension_reduction('svd', reduction_max_features_=50)
lsa_cv_0005_50.KMeans_iterations(10)


# Case 18: 'count', 'nmf', min_df=0.005, reduced_features=50
nmf_cv_0005_50 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
nmf_cv_0005_50.dimension_reduction('nmf', reduction_max_features_=50)
nmf_cv_0005_50.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0005_50.draw_KMeans_plot()
lsa_cv_0005_50.draw_KMeans_plot()
nmf_cv_0005_50.draw_KMeans_plot()

# %%
# min_df=0.005, max_feature =100

# Case 19: 'tfidf', 'svd', min_df=0.005, reduced_features=100
lsa_tfidf_0005_100 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_tfidf_0005_100.dimension_reduction('svd', reduction_max_features_=100)
lsa_tfidf_0005_100.KMeans_iterations(10)


# Case 20: 'count', 'svd', min_df=0.005, reduced_features=100
lsa_cv_0005_100 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_cv_0005_100.dimension_reduction('svd', reduction_max_features_=100)
lsa_cv_0005_100.KMeans_iterations(10)


# Case 21: 'count', 'nmf', min_df=0.005, reduced_features=100
nmf_cv_0005_100 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
nmf_cv_0005_100.dimension_reduction('nmf', reduction_max_features_=100)
nmf_cv_0005_100.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0005_100.draw_KMeans_plot()
lsa_cv_0005_100.draw_KMeans_plot()
nmf_cv_0005_100.draw_KMeans_plot()

# %%
# min_df=0.005, max_feature =200

# Case 22: 'tfidf', 'svd', min_df=0.005, reduced_features=200
lsa_tfidf_0005_200 = KMeansEngine(X, 'tfidf', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_tfidf_0005_200.dimension_reduction('svd', reduction_max_features_=200)
lsa_tfidf_0005_200.KMeans_iterations(10)


# Case 23: 'count', 'svd', min_df=0.005, reduced_features=200
lsa_cv_0005_200 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
lsa_cv_0005_200.dimension_reduction('svd', reduction_max_features_=200)
lsa_cv_0005_200.KMeans_iterations(10)


# Case 24: 'count', 'nmf', min_df=0.005, reduced_features=200
nmf_cv_0005_200 = KMeansEngine(X, 'count', max_df_=0.05, min_df_=0.005, vector_max_features_=2000)
nmf_cv_0005_200.dimension_reduction('nmf', reduction_max_features_=200)
nmf_cv_0005_200.KMeans_iterations(10)


# Plot for all three cases
lsa_tfidf_0005_200.draw_KMeans_plot()
lsa_cv_0005_200.draw_KMeans_plot()
nmf_cv_0005_200.draw_KMeans_plot()

# %%
# optimized model is nmf_cv_0002_100

km_optimized = nmf_cv_0005_25.KMeans_model(2)
labels = km_optimized.labels_

# %%
# Create a list of models for pickle

model_list=[lsa_tfidf_0002_50, lsa_cv_0002_50, nmf_cv_0002_50,
           lsa_tfidf_0002_100, lsa_cv_0002_100, nmf_cv_0002_100,
           lsa_tfidf_0002_200, lsa_cv_0002_200, nmf_cv_0002_200,
           lsa_tfidf_0005_50, lsa_cv_0005_50, nmf_cv_0005_50,
           lsa_tfidf_0005_100, lsa_cv_0005_100, nmf_cv_0005_100,
           lsa_tfidf_0005_200, lsa_cv_0005_200, nmf_cv_0005_200]

# %%
# This is to load pickle file if data is available,
# or store data when pickle file isn't available

pkl_path2 = '/Users/xzhou/github/project_files/amazon/amazon_optimized_km.pkl'

try:    
    with open(pkl_path2, 'rb') as pkl_file:
        km_optimized = pickle.load(pkl_file)
except:
    with open(pkl_path2, 'wb') as pkl_file:
        pickle.dump(km_optimized, pkl_file)

# %%
# This is to load pickle file if data is available,
# or store data when pickle file isn't available

pkl_path3 = '/Users/xzhou/github/project_files/amazon/amazon_km_models.pkl'
models = {}

try:    
    with open(pkl_path3, 'rb') as pkl_file:
        for i in range (18):
            models[i] = pickle.load(pkl_file)
except:
    with open(pkl_path3, 'wb') as pkl_file:
        for item in model_list:
            pickle.dump(item, pkl_file)

# %%
# how to save the model?
# This is to load pickle file if data is available,
# or store data when pickle file isn't available

# pkl_path3 = '/Users/xzhou/github/project_files/amazon/amazon_km_7clusters.pkl'

# try:    
#     with open(pkl_path2, 'rb') as pkl_file:
#         km_optimized = pickle.load(pkl_file)
# except:
#     with open(pkl_path2, 'wb') as pkl_file:
#         pickle.dump(km_optimized, pkl_file)

# %%
centroids = km_optimized.cluster_centers_

# %%
centroids.shape

# %%
km_optimized.cluster_centersers_

# %%
print (centroids_reversed)

# %%
df['label'] = labels

# %%
df[df['label']==0]

# %%
df[df['label']==1]

# %%
len(X)

# %%
cv_data=CountVectorizer().fit_transform(X)

# %%
X

# %%
cv_data.toarray()

# %%
count_vector.get_feature_names()

# %%
# Use WordNetLemmatizer to get the root word.

def get_lemma(word):
    try:
        lemma = wn.morphy(word)
    except:
        lemma = word
    return lemma

def get_lemma2(sentence):
    return [WordNetLemmatizer().lemmatize(word) for word in word_tokenize(sentence)]

# %%
stop_words = set(stopwords.words('English'))
other_words = 'one', 'fun'
stop_words.extend()

# %%
s='abc adef iiiel ll'
b=re.findall(r"\b[a-z][a-z]+\b", s)
b

# %%
parser = English()


def tokenize(text):
    lda_tokens = []
    tokens = parser(text.strip().lower())
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        else:
            lda_tokens.append(token.lower_)
#     for index, token in enumerate(lda_tokens):
#         try:
#             n_gram2 = str(lda_tokens[index]) + ' ' +  str(lda_tokens[index+1])
#             lda_tokens.append(n_gram2)
#         except:
#             contine
        
    return lda_tokens

# %%
def text_processing(sentence):
    
    words = tokenize(sentence)
    words = [word for word in words if len(words)>5]
    words = [word for word in words if word not in stop_words]
    words = [get_lemma(word) for word in words]
    
    return words

# %%
text_data = []

for line in X:
    tokens = text_processing(line)
    tokens=[token for token in tokens if token is not None]
    text_data.append(tokens)

# %%
text_data

# %%
dictionary = corpora.Dictionary(text_data)
#print(dictionary)
corpus = [dictionary.doc2bow(text) for text in text_data]

# %%
num_topics = 5

lda = LdaModel(corpus=corpus,  num_topics=num_topics, id2word=dictionary, passes=5) #
lda.save('test')

# %%
topics = lda.print_topics(num_words=4)
for topic in topics:
    print(topic)

# %%
# Use WordNetLemmatizer to get the root word.

def get_lemma(word):
    try:
        lemma = wn.morphy(word)
    except:
        lemma = word
    return lemma

def get_lemma2(sentence):
    return [WordNetLemmatizer().lemmatize(word) for word in word_tokenize(sentence)]

# %%
parser = English()

from nltk.tokenize import RegexpTokenizer



def tokenize(text):
    lda_tokens = []
    text=text.strip().lower()
    
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(text)
    tokens = [token for token in tokens if (not token.isspace())]
    
    
   # tokens = nltk.word_tokenize(text)
    #tokens = [token for token in tokens if token not in string.punctuation]
    bigrams = ngrams(tokens, 2)
    
    for token in tokens:
        lda_tokens.append(token)
    
    for bg, count in Counter(bigrams).most_common():
        token_string = []
        token_string = str(bg[0]) + " " + str(bg[1])
        lda_tokens.append(token_string)

    
   # tokens = parser(text.strip().lower())
#     for token in tokens:
#         if token.orth_.isspace():
#             continue
#         elif token.like_url:
#             lda_tokens.append('URL')
#         else:
#             lda_tokens.append(token.lower_)
#     for index, token in enumerate(lda_tokens):
#         try:
#             n_gram2 = str(lda_tokens[index]) + ' ' +  str(lda_tokens[index+1])
#             lda_tokens.append(n_gram2)
#         except:
#             contine
    #print(lda_tokens)
    return lda_tokens

# %%
def text_processing(sentence):
    
    words = tokenize(sentence)
    words = [word for word in words if len(words)>5]
    words = [word for word in words if word not in stop_words]
    words = [get_lemma(word) for word in words]
    
    return words

# %%
text_data = []

for line in X_negative:
    tokens = text_processing(line)
    tokens=[token for token in tokens if token is not None]
    text_data.append(tokens)
text_data
# Out:
# ['it', 's', 'like', 'siri', 'in', 'fact', 'siri', 'answers', 'more', 'accurately', 'then', 'alexa', 'i', 'don', 't', 'see', 'a', 'real', 'need', 'for', 'it', 'in', 'my', 'household', 'though', 'it', 'was', 'a', 'good', 'bargain', 'on', 'prime', 'day', 'deals', 'it s', 's like', 'like siri', 'siri in', 'in fact', 'fact siri', 'siri answers', 'answers more', 'more accurately', 'accurately then', 'then alexa', 'alexa i', 'i don', 'don t', 't see', 'see a', 'a real', 'real need', 'need for', 'for it', 'it in', 'in my', 'my household', 'household though', 'though it', 'it was', 'was a', 'a good', 'good bargain', 'bargain on', 'on prime', 'prime day', 'day deals']
# ['sound', 'is', 'terrible', 'if', 'u', 'want', 'good', 'music', 'too', 'get', 'a', 'bose', 'sound is', 'is terrible', 'terrible if', 'if u', 'u want', 'want good', 'good music', 'music too', 'too get', 'get a', 'a bose']
# ['stopped', 'working', 'after', '2', 'weeks', 'didn', 't', 'follow', 'commands', 'really', 'fun', 'when', 'it', 'was', 'working', 'stopped working', 'working after', 'after 2', '2 weeks', 'weeks didn', 'didn t', 't follow', 'follow commands', 'commands really', 'really fun', 'fun when', 'when it', 'it was', 'was working']
# ['sad', 'joke', 'worthless', 'sad joke', 'joke worthless']
# ['really', 'disappointed', 'alexa', 'has', 'to', 'be', 'plug', 'in', 'to', 'wall', 'socket', 'all', 'the', 'time', 'my', 'fault', 'for', 'not', 'checking', 'this', 'but', 'made', 'the', 'assumption', 'that', 'a', 'company', 'has', 'technologically', 'advanced', 'as', 'amazon', 'would', 'sell', 'this', 'product', 'with', 'a', 'rechargeable', 'battery', 'if', 'i', 'could', 'return', 'it', 'i', 'would', 'as', 'my', 'apple', 'music', 'and', 'boom', 'speaker', 'give', 'me', 'more', 'flexibility', 'the', 'alexa', 'really disappointed', 'disappointed alexa', 'alexa has', 'has to', 'to be', 'be plug', 'plug in', 'in to', 'to wall', 'wall socket', 'socket all', 'all the', 'the time', 'time my', 'my fault', 'fault for', 'for not', 'not checking', 'checking this', 'this but', 'but made', 'made the', 'the assumption', 'assumption that', 'that a', 'a company', 'company has', 'has technologically', 'technologically advanced', 'advanced as', 'as amazon', 'amazon would', 'would sell', 'sell this', 'this product', 'product with', 'with a', 'a rechargeable', 'rechargeable battery', 'battery if', 'if i', 'i could', 'could return', 'return it', 'it i', 'i would', 'would as', 'as my', 'my apple', 'apple music', 'music and', 'and boom', 'boom speaker', 'speaker give', 'give me', 'me more', 'more flexibility', 'flexibility the', 'the alexa']
# ['it', 's', 'got', 'great', 'sound', 'and', 'bass', 'but', 'it', 'doesn', 't', 'work', 'all', 'of', 'the', 'time', 'its', 'still', 'hot', 'or', 'miss', 'when', 'it', 'recognizes', 'things', 'it s', 's got', 'got great', 'great sound', 'sound and', 'and bass', 'bass but', 'but it', 'it doesn', 'doesn t', 't work', 'work all', 'all of', 'of the', 'the time', 'time its', 'its still', 'still hot', 'hot or', 'or miss', 'miss when', 'when it', 'it recognizes', 'recognizes things']
# ['i', 'am', 'not', 'super', 'impressed', 'with', 'alexa', 'when', 'my', 'prime', 'lapsed', 'she', 'wouldn', 't', 'play', 'anything', 'she', 'isn', 't', 'smart', 'enough', 'to', 'differentiate', 'among', 'spotify', 'accounts', 'so', 'we', 'can', 't', 'use', 'it', 'for', 'that', 'either', 'she', 'randomly', 'speaks', 'up', 'when', 'nobody', 'is', 'talking', 'to', 'her', 'just', 'today', 'i', 'unplugged', 'her', 'not', 'sure', 'i', 'll', 'ever', 'use', 'my', 'alexa', 'again', 'i am', 'am not', 'not super', 'super impressed', 'impressed with', 'with alexa', 'alexa when', 'when my', 'my prime', 'prime lapsed', 'lapsed she', 'she wouldn', 'wouldn t', 't play', 'play anything', 'anything she', 'she isn', 'isn t', 't smart', 'smart enough', 'enough to', 'to differentiate', 'differentiate among', 'among spotify', 'spotify accounts', 'accounts so', 'so we', 'we can', 'can t', 't use', 'use it', 'it for', 'for that', 'that either', 'either she', 'she randomly', 'randomly speaks', 'speaks up', 'up when', 'when nobody', 'nobody is', 'is talking', 'talking to', 'to her', 'her just', 'just today', 'today i', 'i unplugged', 'unplugged her', 'her not', 'not sure', 'sure i', 'i ll', 'll ever', 'ever use', 'use my', 'my alexa', 'alexa again']
# ['too', 'difficult', 'to', 'set', 'up', 'it', 'keeps', 'timing', 'out', 'before', 'you', 'can', 'enter', 'the', 'password', 'too difficult', 'difficult to', 'to set', 'set up', 'up it', 'it keeps', 'keeps timing', 'timing out', 'out before', 'before you', 'you can', 'can enter', 'enter the', 'the password']
# ['item', 'no', 'longer', 'works', 'after', 'just', '5', 'months', 'of', 'use', 'will', 'not', 'connect', 'to', 'wifi', 'and', 'unresponsive', 'to', 'reset', 'requests', 'item no', 'no longer', 'longer works', 'works after', 'after just', 'just 5', '5 months', 'months of', 'of use', 'use will', 'will not', 'not connect', 'connect to', 'to wifi', 'wifi and', 'and unresponsive', 'unresponsive to', 'to reset', 'reset requests']
# ['this', 'thing', 'barely', 'works', 'you', 'have', 'to', 'select', '3rd', 'party', 'apps', 'to', 'do', 'stuff', 'you', 'd', 'think', 'it', 'could', 'do', 'out', 'of', 'the', 'box', 'i', 'm', 'sending', 'mine', 'back', 'asap', 'waste', 'of', 'money', 'this thing', 'thing barely', 'barely works', 'works you', 'you have', 'have to', 'to select', 'select 3rd', '3rd party', 'party apps', 'apps to', 'to do', 'do stuff', 'stuff you', 'you d', 'd think', 'think it', 'it could', 'could do', 'do out', 'out of', 'of the', 'the box', 'box i', 'i m', 'm sending', 'sending mine', 'mine back', 'back asap', 'asap waste', 'waste of', 'of money']
# ['i', 'returned', '2', 'echo', 'dots', 'am', 'only', 'getting', 'refund', 'for', '1', 'i', 'returned', '2', 'in', 'one', 'package', 'i', 'want', 'my', 'refunds', 'for', 'both', 'of', 'them', 'they', 'are', 'in', 'the', 'same', 'package', 'can', 'you', 'not', 'see', 'them', 'both', 'i returned', 'returned 2', '2 echo', 'echo dots', 'dots am', 'am only', 'only getting', 'getting refund', 'refund for', 'for 1', '1 i', '2 in', 'in one', 'one package', 'package i', 'i want', 'want my', 'my refunds', 'refunds for', 'for both', 'both of', 'of them', 'them they', 'they are', 'are in', 'in the', 'the same', 'same package', 'package can', 'can you', 'you not', 'not see', 'see them', 'them both']
# ['i', 'm', 'an', 'echo', 'fan', 'but', 'this', 'one', 'did', 'not', 'work', 'i m', 'm an', 'an echo', 'echo fan', 'fan but', 'but this', 'this one', 'one did', 'did not', 'not work']
# ['doesn', 't', 'always', 'respond', 'when', 'spoken', 'to', 'with', 'promp', 'word', 'i', 'thought', 'it', 'would', 'connect', 'to', 'my', 'echo', 'upstairs', 'and', 'use', 'it', 'like', 'an', 'intercom', 'haven', 't', 'been', 'able', 'to', 'do', 'that', 'doesn t', 't always', 'always respond', 'respond when', 'when spoken', 'spoken to', 'to with', 'with promp', 'promp word', 'word i', 'i thought', 'thought it', 'it would', 'would connect', 'connect to', 'to my', 'my echo', 'echo upstairs', 'upstairs and', 'and use', 'use it', 'it like', 'like an', 'an intercom', 'intercom haven', 'haven t', 't been', 'been able', 'able to', 'to do', 'do that']
# ['it', 'worked', 'for', 'a', 'month', 'or', 'so', 'then', 'it', 'stopped', 'i', 've', 'tried', 'everything', 'to', 'try', 'and', 'make', 'it', 'work', 'but', 'nothing', 'is', 'working', 'i', 'want', 'a', 'refund', 'it worked', 'worked for', 'for a', 'a month', 'month or', 'or so', 'so then', 'then it', 'it stopped', 'stopped i', 'i ve', 've tried', 'tried everything', 'everything to', 'to try', 'try and', 'and make', 'make it', 'it work', 'work but', 'but nothing', 'nothing is', 'is working', 'working i', 'i want', 'want a', 'a refund']
# ['poor', 'quality', 'gave', 'it', 'away', 'poor quality', 'quality gave', 'gave it', 'it away']
# ['never', 'could', 'get', 'it', 'to', 'work', 'a', 'techie', 'friend', 'looked', 'at', 'it', 'for', 'me', 'and', 'said', 'the', 'adapter', 'wasn', 't', 'strong', 'enough', 'to', 'power', 'it', 'and', 'that', 'it', 'looked', 'like', 'it', 'had', 'been', 'bought', 'at', 'a', 'dollar', 'store', 'so', 'i', 'am', 'going', 'to', 'replace', 'the', 'adapter', 'and', 'hope', 'it', 'works', 'then', 'the adapter', 'never could', 'could get', 'get it', 'it to', 'to work', 'work a', 'a techie', 'techie friend', 'friend looked', 'looked at', 'at it', 'it for', 'for me', 'me and', 'and said', 'said the', 'adapter wasn', 'wasn t', 't strong', 'strong enough', 'enough to', 'to power', 'power it', 'it and', 'and that', 'that it', 'it looked', 'looked like', 'like it', 'it had', 'had been', 'been bought', 'bought at', 'at a', 'a dollar', 'dollar store', 'store so', 'so i', 'i am', 'am going', 'going to', 'to replace', 'replace the', 'adapter and', 'and hope', 'hope it', 'it works', 'works then']
# ['initially', 'this', 'echo', 'dot', 'worked', 'very', 'well', 'over', 'time', 'the', 'dot', 'stopped', 'responding', 'to', 'alexa', 'unless', 'you', 'were', 'within', 'one', 'foot', 'of', 'it', 'yelling', 'the', 'other', 'echos', 'echo', 'dots', 'in', 'other', 'rooms', 'would', 'respond', 'without', 'a', 'response', 'from', 'this', 'echo', 'dot', 'would', 'not', 'recommend', 'buying', 'refurbished', 'this echo', 'echo dot', 'initially this', 'dot worked', 'worked very', 'very well', 'well over', 'over time', 'time the', 'the dot', 'dot stopped', 'stopped responding', 'responding to', 'to alexa', 'alexa unless', 'unless you', 'you were', 'were within', 'within one', 'one foot', 'foot of', 'of it', 'it yelling', 'yelling the', 'the other', 'other echos', 'echos echo', 'echo dots', 'dots in', 'in other', 'other rooms', 'rooms would', 'would respond', 'respond without', 'without a', 'a response', 'response from', 'from this', 'dot would', 'would not', 'not recommend', 'recommend buying', 'buying refurbished']
# ['i', 'bought', 'an', 'echo', 'dot', 'that', 'had', 'been', 'refurbished', 'but', 'its', 'stops', 'whatever', 'function', 'its', 'performing', 'quite', 'often', 'doesn', 't', 'wake', 'up', 'every', 'time', 'randomly', 'turns', 'on', 'but', 'does', 'nothing', 'do', 'not', 'buy', 'a', 'refurbished', 'echo', 'dot', 'echo dot', 'i bought', 'bought an', 'an echo', 'dot that', 'that had', 'had been', 'been refurbished', 'refurbished but', 'but its', 'its stops', 'stops whatever', 'whatever function', 'function its', 'its performing', 'performing quite', 'quite often', 'often doesn', 'doesn t', 't wake', 'wake up', 'up every', 'every time', 'time randomly', 'randomly turns', 'turns on', 'on but', 'but does', 'does nothing', 'nothing do', 'do not', 'not buy', 'buy a', 'a refurbished', 'refurbished echo']
# ['dont', 'trust', 'this', 'dont trust', 'trust this']
# ['i', 'wanted', 'to', 'use', 'these', 'as', 'a', 'radio', 'and', 'intercom', 'as', 'we', 'get', 'terrible', 'fm', 'reception', 'where', 'i', 'live', 'the', 'speech', 'recognition', 'software', 'is', 'horrible', 'my', 'wife', 'and', 'i', 'both', 'are', 'native', 'americans', 'whose', 'language', 'is', 'english', 'she', 'is', 'from', 'the', 'north', 'i', 'am', 'from', 'texas', 'neither', 'have', 'an', 'accent', 'from', 'our', 'birth', 'area', 'and', 'yet', 'it', 'does', 'not', 'do', 'a', 'good', 'job', 'understanding', 'us', 'we', 'bought', 'two', 'they', 'do', 'the', 'same', 'thing', 'additionally', 'wifi', 'reception', 'was', 'poor', 'to', 'marginal', 'i', 'had', 'to', 'buy', 'wifi', 'range', 'extender', 'for', 'office', 'and', 'the', 'other', 'is', 'ten', 'feet', 'from', 'our', 'router', 'both', 'had', 'problems', 'switched', 'them', 'around', 'no', 'difference', 'so', 'it', 'they', 'are', 'now', 'disconnected', 'dust', 'collectors', 'from our', 'i wanted', 'wanted to', 'to use', 'use these', 'these as', 'as a', 'a radio', 'radio and', 'and intercom', 'intercom as', 'as we', 'we get', 'get terrible', 'terrible fm', 'fm reception', 'reception where', 'where i', 'i live', 'live the', 'the speech', 'speech recognition', 'recognition software', 'software is', 'is horrible', 'horrible my', 'my wife', 'wife and', 'and i', 'i both', 'both are', 'are native', 'native americans', 'americans whose', 'whose language', 'language is', 'is english', 'english she', 'she is', 'is from', 'from the', 'the north', 'north i', 'i am', 'am from', 'from texas', 'texas neither', 'neither have', 'have an', 'an accent', 'accent from', 'our birth', 'birth area', 'area and', 'and yet', 'yet it', 'it does', 'does not', 'not do', 'do a', 'a good', 'good job', 'job understanding', 'understanding us', 'us we', 'we bought', 'bought two', 'two they', 'they do', 'do the', 'the same', 'same thing', 'thing additionally', 'additionally wifi', 'wifi reception', 'reception was', 'was poor', 'poor to', 'to marginal', 'marginal i', 'i had', 'had to', 'to buy', 'buy wifi', 'wifi range', 'range extender', 'extender for', 'for office', 'office and', 'and the', 'the other', 'other is', 'is ten', 'ten feet', 'feet from', 'our router', 'router both', 'both had', 'had problems', 'problems switched', 'switched them', 'them around', 'around no', 'no difference', 'difference so', 'so it', 'it they', 'they are', 'are now', 'now disconnected', 'disconnected dust', 'dust collectors']
# ['item', 'has', 'never', 'worked', 'out', 'of', 'box', 'it', 'is', 'broken', 'spent', 'several', 'days', 'trying', 'to', 'get', 'it', 'working', 'and', 'running', 'same', '34', 'fixes', '34', 'from', 'amazon', 'the', 'only', 'thing', 'accomplished', 'is', 'i', 'will', 'never', 'order', 'another', 'refurbished', 'device', 'item has', 'has never', 'never worked', 'worked out', 'out of', 'of box', 'box it', 'it is', 'is broken', 'broken spent', 'spent several', 'several days', 'days trying', 'trying to', 'to get', 'get it', 'it working', 'working and', 'and running', 'running same', 'same 34', '34 fixes', 'fixes 34', '34 from', 'from amazon', 'amazon the', 'the only', 'only thing', 'thing accomplished', 'accomplished is', 'is i', 'i will', 'will never', 'never order', 'order another', 'another refurbished', 'refurbished device']
# ['great', 'product', 'but', 'returning', 'for', 'new', 'alexa', 'dot', 'refurbished', 'is', 'already', 'giving', 'me', 'problems', 'with', 'connection', 'great product', 'product but', 'but returning', 'returning for', 'for new', 'new alexa', 'alexa dot', 'dot refurbished', 'refurbished is', 'is already', 'already giving', 'giving me', 'me problems', 'problems with', 'with connection']
# ['34', 'never', 'buy', 'certified', 'and', 'refurbished', 'echo', 'dot', '34', 'i', 'bought', 'a', '34', 'certified', 'and', 'refurbished', '34', 'echo', 'dot', 'this', 'unit', 'is', 'very', 'poor', 'in', 'receiving', 'command', 'and', 'sometimes', 'it', 'does', 'not', 'even', 'acknowledge', 'the', 'command', 'never', 'buy', 'a', 'refurbished', 'echo', 'dot', 'the', 'unit', 'i', 'received', 'was', 'probably', 'never', 'was', 'certified', 'and', 'refurbished', 'as', 'indicated', 'i', 'also', 'bought', 'a', 'new', 'echo', 'dot', 'it', 'works', 'perfectly', 'very', 'disappointed', 'echo dot', 'certified and', 'and refurbished', 'never buy', 'refurbished echo', 'bought a', '34 never', 'buy certified', 'dot 34', '34 i', 'i bought', 'a 34', '34 certified', 'refurbished 34', '34 echo', 'dot this', 'this unit', 'unit is', 'is very', 'very poor', 'poor in', 'in receiving', 'receiving command', 'command and', 'and sometimes', 'sometimes it', 'it does', 'does not', 'not even', 'even acknowledge', 'acknowledge the', 'the command', 'command never', 'buy a', 'a refurbished', 'dot the', 'the unit', 'unit i', 'i received', 'received was', 'was probably', 'probably never', 'never was', 'was certified', 'refurbished as', 'as indicated', 'indicated i', 'i also', 'also bought', 'a new', 'new echo', 'dot it', 'it works', 'works perfectly', 'perfectly very', 'very disappointed']
# ['this', 'item', 'did', 'not', 'work', 'certified', 'refurbished', 'should', 'mean', 'it', 'works', 'as', 'advertised', 'instead', 'this', 'item', 'crashed', 'as', 'soon', 'as', 'i', 'turned', 'it', 'on', 'and', 'plugged', 'it', 'in', 'when', 'trying', 'to', 'connect', 'from', 'my', 'phone', 'to', 'the', 'echo', 'dot', 'it', 'crashed', 'over', 'and', 'over', 'not', 'only', 'would', 'it', 'disconnect', 'but', 'the', 'orange', 'light', 'would', 'freeze', 'and', 'then', 'the', 'thing', 'would', 'reboot', 'with', 'the', 'blue', 'light', 'alexa', 'would', 'tell', 'me', 'it', 's', 'ready', 'to', 'connect', 'and', 'freeze', 'mid', 'sentence', 'tried', 'holding', 'the', 'action', 'button', 'for', '5', 'seconds', 'and', 'it', 'didn', 't', 'do', 'anything', 'returning', 'immediately', 'and', 'hope', 'they', 'actually', 'fix', 'this', 'item', 'when', 'the', 'next', 'buyer', 'purchases', 'it', 'this item', 'to connect', 'item did', 'did not', 'not work', 'work certified', 'certified refurbished', 'refurbished should', 'should mean', 'mean it', 'it works', 'works as', 'as advertised', 'advertised instead', 'instead this', 'item crashed', 'crashed as', 'as soon', 'soon as', 'as i', 'i turned', 'turned it', 'it on', 'on and', 'and plugged', 'plugged it', 'it in', 'in when', 'when trying', 'trying to', 'connect from', 'from my', 'my phone', 'phone to', 'to the', 'the echo', 'echo dot', 'dot it', 'it crashed', 'crashed over', 'over and', 'and over', 'over not', 'not only', 'only would', 'would it', 'it disconnect', 'disconnect but', 'but the', 'the orange', 'orange light', 'light would', 'would freeze', 'freeze and', 'and then', 'then the', 'the thing', 'thing would', 'would reboot', 'reboot with', 'with the', 'the blue', 'blue light', 'light alexa', 'alexa would', 'would tell', 'tell me', 'me it', 'it s', 's ready', 'ready to', 'connect and', 'and freeze', 'freeze mid', 'mid sentence', 'sentence tried', 'tried holding', 'holding the', 'the action', 'action button', 'button for', 'for 5', '5 seconds', 'seconds and', 'and it', 'it didn', 'didn t', 't do', 'do anything', 'anything returning', 'returning immediately', 'immediately and', 'and hope', 'hope they', 'they actually', 'actually fix', 'fix this', 'item when', 'when the', 'the next', 'next buyer', 'buyer purchases', 'purchases it']
# ['does', 'not', 'work', 'all', 'the', 'time', 'does not', 'not work', 'work all', 'all the', 'the time']
# ['i', 've', 'already', 'returned', 'it', 'i ve', 've already', 'already returned', 'returned it']
# ['now', 'i', 'm', 'weary', 'about', 'these', 'picking', 'up', 'conversations', 'when', 'you', 'are', 'not', 'actively', 'using', 'them', 'heard', 'about', 'this', 'happening', 'on', 'the', 'news', 'i', 'have', '3', '4', 'so', 'this', 'is', 'very', 'concerning', 'i', 'wish', 'amazon', 'would', 'release', 'something', 'widespread', 'or', 'push', 'some', 'firmware', 'to', 'prevent', 'this', 'if', 'they', 'have', 'i', 'have', 'not', 'heard', 'about', 'it', 'yet', 'heard about', 'i have', 'now i', 'i m', 'm weary', 'weary about', 'about these', 'these picking', 'picking up', 'up conversations', 'conversations when', 'when you', 'you are', 'are not', 'not actively', 'actively using', 'using them', 'them heard', 'about this', 'this happening', 'happening on', 'on the', 'the news', 'news i', 'have 3', '3 4', '4 so', 'so this', 'this is', 'is very', 'very concerning', 'concerning i', 'i wish', 'wish amazon', 'amazon would', 'would release', 'release something', 'something widespread', 'widespread or', 'or push', 'push some', 'some firmware', 'firmware to', 'to prevent', 'prevent this', 'this if', 'if they', 'they have', 'have i', 'have not', 'not heard', 'about it', 'it yet']
# ['there', 'was', 'something', 'wrong', 'with', 'the', 'first', 'one', 'that', 'no', 'even', 'the', 'rep', 'i', 'spoke', 'with', 'could', 'fix', 'the', 'replacement', 'was', 'registered', 'to', 'someone', 'else', 'when', 'the', 'price', 'of', 'the', 'dot', 'went', 'down', 'to', '39', '99', 'same', 'price', 'as', 'the', 'refurbished', 'ones', 'i', 'bought', 'a', 'brand', 'spanking', 'new', 'one', 'no', 'problem', 'with', 'the', 'new', 'one', 'with the', 'new one', 'there was', 'was something', 'something wrong', 'wrong with', 'the first', 'first one', 'one that', 'that no', 'no even', 'even the', 'the rep', 'rep i', 'i spoke', 'spoke with', 'with could', 'could fix', 'fix the', 'the replacement', 'replacement was', 'was registered', 'registered to', 'to someone', 'someone else', 'else when', 'when the', 'the price', 'price of', 'of the', 'the dot', 'dot went', 'went down', 'down to', 'to 39', '39 99', '99 same', 'same price', 'price as', 'as the', 'the refurbished', 'refurbished ones', 'ones i', 'i bought', 'bought a', 'a brand', 'brand spanking', 'spanking new', 'one no', 'no problem', 'problem with', 'the new']
# ['two', 'weeks', 'after', 'setting', 'it', 'up', 'it', 'no', 'longer', 'works', 'no', 'connection', 'no', 'light', 'no', 'sound', 'i', 'guess', 'i', 'shouldn', 't', 'have', 'purchased', 'a', 'refurbished', 'dot', 'two weeks', 'weeks after', 'after setting', 'setting it', 'it up', 'up it', 'it no', 'no longer', 'longer works', 'works no', 'no connection', 'connection no', 'no light', 'light no', 'no sound', 'sound i', 'i guess', 'guess i', 'i shouldn', 'shouldn t', 't have', 'have purchased', 'purchased a', 'a refurbished', 'refurbished dot']
# ['not', 'good', 'at', 'all', 'not good', 'good at', 'at all']
# ['this', 'is', 'the', 'worst', 'amazon', 'purchase', 'i', 'have', 'made', 'i', 'am', 'big', 'amazon', 'fan', 'love', 'the', 'brand', 'unlimited', 'digital', 'music', 'prime', 'videos', 'even', 'buy', 'my', 'online', 'games', 'music', 'and', 'movies', 'through', 'amazon', 'this', 'app', 'i', 'have', 'tried', 'to', 'use', 'it', 'make', 'simple', 'purchases', 'to', 'do', 'anything', 'it', 'is', 'useless', 'i have', 'this is', 'is the', 'the worst', 'worst amazon', 'amazon purchase', 'purchase i', 'have made', 'made i', 'i am', 'am big', 'big amazon', 'amazon fan', 'fan love', 'love the', 'the brand', 'brand unlimited', 'unlimited digital', 'digital music', 'music prime', 'prime videos', 'videos even', 'even buy', 'buy my', 'my online', 'online games', 'games music', 'music and', 'and movies', 'movies through', 'through amazon', 'amazon this', 'this app', 'app i', 'have tried', 'tried to', 'to use', 'use it', 'it make', 'make simple', 'simple purchases', 'purchases to', 'to do', 'do anything', 'anything it', 'it is', 'is useless']
# ['the', 'echo', 'dot', 'disconnects', 'from', 'the', 'speaker', 'about', '12', '20', 'times', 'a', 'day', 'do', 'not', 'buy', 'the', 'refurbished', 'product', '2', 'stars', 'for', 'effort', 'the echo', 'echo dot', 'dot disconnects', 'disconnects from', 'from the', 'the speaker', 'speaker about', 'about 12', '12 20', '20 times', 'times a', 'a day', 'day do', 'do not', 'not buy', 'buy the', 'the refurbished', 'refurbished product', 'product 2', '2 stars', 'stars for', 'for effort']
# ['cant', 'seem', 'to', 'get', 'this', 'thing', 'to', 'sink', 'with', 'my', 'wireless', 'not', 'sure', 'if', 'i', 'will', 'be', 'returning', 'it', 'will', 'try', 'one', 'more', 'time', 'cant seem', 'seem to', 'to get', 'get this', 'this thing', 'thing to', 'to sink', 'sink with', 'with my', 'my wireless', 'wireless not', 'not sure', 'sure if', 'if i', 'i will', 'will be', 'be returning', 'returning it', 'it will', 'will try', 'try one', 'one more', 'more time']
# ['product', 'stopped', 'working', 'after', 'return', 'time', 'ran', 'out', 'product stopped', 'stopped working', 'working after', 'after return', 'return time', 'time ran', 'ran out']
# ['stopped', 'working', 'after', '7', 'months', 'the', 'warranty', 'was', 'only', 'good', 'for', '3', 'months', 'i', 'would', 'have', 'assumed', 'an', 'amazon', 'product', 'sold', 'on', 'amazon', 'would', 'have', 'had', 'higher', 'standards', 'than', 'guaranteeing', 'that', 'it', 'would', 'work', 'for', '3', 'whole', 'months', 'i', 'mean', 'what', 'is', 'this', 'product', 'supposed', 'to', 'be', 'a', 'piece', 'of', 'junk', 'they', 'offered', 'my', 'a', '15', 'discount', 'if', 'i', 'wanted', 'to', 'buy', 'another', 'one', 'why', 'would', 'i', 'want', 'to', 'buy', 'another', 'one', 'for 3', 'months i', 'would have', 'to buy', 'buy another', 'another one', 'stopped working', 'working after', 'after 7', '7 months', 'months the', 'the warranty', 'warranty was', 'was only', 'only good', 'good for', '3 months', 'i would', 'have assumed', 'assumed an', 'an amazon', 'amazon product', 'product sold', 'sold on', 'on amazon', 'amazon would', 'have had', 'had higher', 'higher standards', 'standards than', 'than guaranteeing', 'guaranteeing that', 'that it', 'it would', 'would work', 'work for', '3 whole', 'whole months', 'i mean', 'mean what', 'what is', 'is this', 'this product', 'product supposed', 'supposed to', 'to be', 'be a', 'a piece', 'piece of', 'of junk', 'junk they', 'they offered', 'offered my', 'my a', 'a 15', '15 discount', 'discount if', 'if i', 'i wanted', 'wanted to', 'one why', 'why would', 'would i', 'i want', 'want to']
# ['bought', 'this', 'for', 'my', 'son', 'and', 'it', 'didn', 't', 'work', 'he', 'had', 'to', 'return', 'it', 'bought this', 'this for', 'for my', 'my son', 'son and', 'and it', 'it didn', 'didn t', 't work', 'work he', 'he had', 'had to', 'to return', 'return it']
# ['bought', '2', 'and', 'both', 'quit', 'connecting', 'to', 'wifi', 'and', 'responding', 'to', 'voice', 'within', '9', 'months', 'hard', 'and', 'soft', 'reset', 'will', 'not', 'fix', 'the', 'problem', 'bought 2', '2 and', 'and both', 'both quit', 'quit connecting', 'connecting to', 'to wifi', 'wifi and', 'and responding', 'responding to', 'to voice', 'voice within', 'within 9', '9 months', 'months hard', 'hard and', 'and soft', 'soft reset', 'reset will', 'will not', 'not fix', 'fix the', 'the problem']
# ['the', 'second', 'one', 'which', 'was', 'a', 'refurbished', 'model', 'did', 'work', 'at', 'least', 'not', 'in', 'my', 'home', 'the second', 'second one', 'one which', 'which was', 'was a', 'a refurbished', 'refurbished model', 'model did', 'did work', 'work at', 'at least', 'least not', 'not in', 'in my', 'my home']
# ['very', 'bad', 'this', 'device', 'i', 'don', 't', 'know', 'if', 'it', 's', 'because', 'is', 'refurbished', 'or', 'what', 'but', 'it', 'activated', 'by', 'itself', 'nobody', 'is', 'talking', 'and', 'he', 'just', 'activated', 'and', 'start', 'talking', 'when', 'you', 'talk', 'you', 'have', 'to', 'yell', 'super', 'lauded', 'very bad', 'bad this', 'this device', 'device i', 'i don', 'don t', 't know', 'know if', 'if it', 'it s', 's because', 'because is', 'is refurbished', 'refurbished or', 'or what', 'what but', 'but it', 'it activated', 'activated by', 'by itself', 'itself nobody', 'nobody is', 'is talking', 'talking and', 'and he', 'he just', 'just activated', 'activated and', 'and start', 'start talking', 'talking when', 'when you', 'you talk', 'talk you', 'you have', 'have to', 'to yell', 'yell super', 'super lauded']
# ['so', 'far', 'not', 'impressed', 'at', 'all', 'does', 'not', 'save', 'groups', 'correctly', 'can', 'not', 'understand', 'me', 'most', 'of', 'the', 'time', 'i', 'm', 'not', 'sure', 'what', 'the', 'excitement', 'is', 'all', 'about', 'alexas', 'voice', 'sounds', 'like', 'it', 's', 'under', 'water', 'how', 'am', 'i', 'supposed', 'to', 'understand', 'i', 'm', 'going', 'to', 'return', 'and', 'try', 'a', 'google', 'home', 'i m', 'so far', 'far not', 'not impressed', 'impressed at', 'at all', 'all does', 'does not', 'not save', 'save groups', 'groups correctly', 'correctly can', 'can not', 'not understand', 'understand me', 'me most', 'most of', 'of the', 'the time', 'time i', 'm not', 'not sure', 'sure what', 'what the', 'the excitement', 'excitement is', 'is all', 'all about', 'about alexas', 'alexas voice', 'voice sounds', 'sounds like', 'like it', 'it s', 's under', 'under water', 'water how', 'how am', 'am i', 'i supposed', 'supposed to', 'to understand', 'understand i', 'm going', 'going to', 'to return', 'return and', 'and try', 'try a', 'a google', 'google home']
# ['great', 'product', 'but', 'useless', 'overall', 'too', 'many', 'unnecessary', 'features', 'unless', 'you', 'have', 'a', 'smart', 'home', 'you', 'don', 't', 'need', 'it', 'great product', 'product but', 'but useless', 'useless overall', 'overall too', 'too many', 'many unnecessary', 'unnecessary features', 'features unless', 'unless you', 'you have', 'have a', 'a smart', 'smart home', 'home you', 'you don', 'don t', 't need', 'need it']
# ['i', 'cant', 'figure', 'out', 'how', 'to', 'use', 'it', 'i cant', 'cant figure', 'figure out', 'out how', 'how to', 'to use', 'use it']
# ['it', 'doesn', 't', 'always', 'work', 'it doesn', 'doesn t', 't always', 'always work']
# ['all', 'the', 'new', 'amazon', 'products', 'i', 'have', 'are', 'great', 'everything', 'i', 'bought', 'refurbished', 'is', 'complete', 'garbage', 'i', 'will', 'never', 'purchase', 'amazon', 'refurbished', 'again', 'total', 'dissatisfaction', 'all the', 'the new', 'new amazon', 'amazon products', 'products i', 'i have', 'have are', 'are great', 'great everything', 'everything i', 'i bought', 'bought refurbished', 'refurbished is', 'is complete', 'complete garbage', 'garbage i', 'i will', 'will never', 'never purchase', 'purchase amazon', 'amazon refurbished', 'refurbished again', 'again total', 'total dissatisfaction']
# ['brought', 'to', 'replace', 'one', 'that', 'i', 'moved', 'and', 'doesn', 't', 'have', 'the', 'same', 'range', 'as', 'my', 'previous', 'non', 'refurbished', 'unit', 'it', 'would', 'seldom', 'be', 'able', 'to', 'find', 'the', 'wi', 'fi', 'and', 'couldn', 't', 'connect', 'got', 'tired', 'of', 'hearing', 'the', 'message', '34', 'trouble', 'connecting', 'check', 'the', 'alexa', 'app', '34', 'and', 'just', 'unplugged', 'it', 'i', 'went', 'through', 'the', 'troubleshooting', 'and', 'reconnected', 'it', 'several', 'times', 'it', 's', 'just', 'not', 'as', 'strong', 'brought to', 'to replace', 'replace one', 'one that', 'that i', 'i moved', 'moved and', 'and doesn', 'doesn t', 't have', 'have the', 'the same', 'same range', 'range as', 'as my', 'my previous', 'previous non', 'non refurbished', 'refurbished unit', 'unit it', 'it would', 'would seldom', 'seldom be', 'be able', 'able to', 'to find', 'find the', 'the wi', 'wi fi', 'fi and', 'and couldn', 'couldn t', 't connect', 'connect got', 'got tired', 'tired of', 'of hearing', 'hearing the', 'the message', 'message 34', '34 trouble', 'trouble connecting', 'connecting check', 'check the', 'the alexa', 'alexa app', 'app 34', '34 and', 'and just', 'just unplugged', 'unplugged it', 'it i', 'i went', 'went through', 'through the', 'the troubleshooting', 'troubleshooting and', 'and reconnected', 'reconnected it', 'it several', 'several times', 'times it', 'it s', 's just', 'just not', 'not as', 'as strong']
# ['if', 'you', 'want', 'to', 'listen', 'to', 'music', 'and', 'have', 'it', 'come', 'through', 'several', 'of', 'the', 'echo', 'dot', 'units', 'simultaneously', 'you', 'must', 'pay', 'a', 'monthly', 'fee', 'i', 'thought', 'this', 'was', 'amazon', 'not', 'apple', 'i', 've', 'paid', 'for', 'many', 'of', 'these', 'so', 'i', 'could', 'have', 'one', 'in', 'each', 'room', 'is', 'that', 'not', 'enough', 'of', 'my', 'money', 'if you', 'you want', 'want to', 'to listen', 'listen to', 'to music', 'music and', 'and have', 'have it', 'it come', 'come through', 'through several', 'several of', 'of the', 'the echo', 'echo dot', 'dot units', 'units simultaneously', 'simultaneously you', 'you must', 'must pay', 'pay a', 'a monthly', 'monthly fee', 'fee i', 'i thought', 'thought this', 'this was', 'was amazon', 'amazon not', 'not apple', 'apple i', 'i ve', 've paid', 'paid for', 'for many', 'many of', 'of these', 'these so', 'so i', 'i could', 'could have', 'have one', 'one in', 'in each', 'each room', 'room is', 'is that', 'that not', 'not enough', 'enough of', 'of my', 'my money']
# ['eh', 'it', 's', 'works', 'on', 'and', 'off', 'half', 'the', 'time', 'it', 'does', 'not', 'respond', 'when', 'you', 'say', 'wake', 'up', 'name', 'other', 'then', 'that', 'works', 'fine', 'eh it', 'it s', 's works', 'works on', 'on and', 'and off', 'off half', 'half the', 'the time', 'time it', 'it does', 'does not', 'not respond', 'respond when', 'when you', 'you say', 'say wake', 'wake up', 'up name', 'name other', 'other then', 'then that', 'that works', 'works fine']
# ['i', 'wanted', 'a', 'white', 'dot', 'for', 'my', 'white', 'bathroom', 'the', 'top', 'is', 'black', 'as', 'shown', 'which', 'i', 'knew', 'but', 'i', 'did', 'not', 'realize', 'the', 'cord', 'and', 'plug', 'were', 'also', 'black', 'i', 'wanted', 'a', 'white', 'cord', 'and', 'plug', 'i wanted', 'wanted a', 'a white', 'cord and', 'and plug', 'white dot', 'dot for', 'for my', 'my white', 'white bathroom', 'bathroom the', 'the top', 'top is', 'is black', 'black as', 'as shown', 'shown which', 'which i', 'i knew', 'knew but', 'but i', 'i did', 'did not', 'not realize', 'realize the', 'the cord', 'plug were', 'were also', 'also black', 'black i', 'white cord']
# ['i', 'set', 'up', 'the', 'echo', 'dot', 'and', 'it', 'worked', 'for', 'an', 'hour', 'and', 'then', 'died', 'completely', 'do', 'not', 'buy', 'refurbished', 'i', 'sent', 'back', 'for', 'return', 'the', 'day', 'after', 'i', 'received', 'i set', 'set up', 'up the', 'the echo', 'echo dot', 'dot and', 'and it', 'it worked', 'worked for', 'for an', 'an hour', 'hour and', 'and then', 'then died', 'died completely', 'completely do', 'do not', 'not buy', 'buy refurbished', 'refurbished i', 'i sent', 'sent back', 'back for', 'for return', 'return the', 'the day', 'day after', 'after i', 'i received']
# ['this', 'echo', 'dot', 'is', 'horrible', 'the', 'volume', 'on', 'my', 'phone', 'is', 'louder', 'than', 'than', 'this', 'device', 'my', 'boss', 'has', 'one', 'at', 'this', 'is', 'not', 'the', 'case', 'this echo', 'echo dot', 'dot is', 'is horrible', 'horrible the', 'the volume', 'volume on', 'on my', 'my phone', 'phone is', 'is louder', 'louder than', 'than than', 'than this', 'this device', 'device my', 'my boss', 'boss has', 'has one', 'one at', 'at this', 'this is', 'is not', 'not the', 'the case']
# ['it', 's', 'ok', 'the', 'speaker', 'is', 'pretty', 'terrible', 'google', 'home', 'is', 'a', 'better', 'product', 'it s', 's ok', 'ok the', 'the speaker', 'speaker is', 'is pretty', 'pretty terrible', 'terrible google', 'google home', 'home is', 'is a', 'a better', 'better product']
# ['the', 'first', 'one', 'quit', 'working', 'shortly', 'after', 'i', 'got', 'it', 'the', 'next', 'one', 'becomes', 'unresponsive', 'to', 'my', 'voice', 'at', 'times', 'and', 'the', 'only', 'way', 'to', 'get', 'it', 'to', 'work', 'is', 'through', 'the', 'app', 'i', 'am', 'not', 'sure', 'if', 'it', 'just', 'this', 'dot', 'or', 'they', 'are', 'all', 'this', 'way', 'the first', 'first one', 'one quit', 'quit working', 'working shortly', 'shortly after', 'after i', 'i got', 'got it', 'it the', 'the next', 'next one', 'one becomes', 'becomes unresponsive', 'unresponsive to', 'to my', 'my voice', 'voice at', 'at times', 'times and', 'and the', 'the only', 'only way', 'way to', 'to get', 'get it', 'it to', 'to work', 'work is', 'is through', 'through the', 'the app', 'app i', 'i am', 'am not', 'not sure', 'sure if', 'if it', 'it just', 'just this', 'this dot', 'dot or', 'or they', 'they are', 'are all', 'all this', 'this way']
# ['device', 'was', 'not', 'working', 'followed', 'all', 'instructions', 'for', 'alexa', 'echo', 'dot', 'and', 'it', 'did', 'not', 'come', 'on', 'very', 'upsetting', 'device was', 'was not', 'not working', 'working followed', 'followed all', 'all instructions', 'instructions for', 'for alexa', 'alexa echo', 'echo dot', 'dot and', 'and it', 'it did', 'did not', 'not come', 'come on', 'on very', 'very upsetting']
# ['sent', 'it', 'back', 'due', 'to', 'crackling', 'noise', 'and', 'turning', 'itself', 'off', 'and', 'on', 'but', 'what', 'can', 'you', 'expect', 'with', 'a', 'refurbished', 'item', 'sent it', 'it back', 'back due', 'due to', 'to crackling', 'crackling noise', 'noise and', 'and turning', 'turning itself', 'itself off', 'off and', 'and on', 'on but', 'but what', 'what can', 'can you', 'you expect', 'expect with', 'with a', 'a refurbished', 'refurbished item']
# ['honestly', 'i', 'like', 'it', 'but', 'at', 'the', 'same', 'time', 'i', 'don', 't', 'i', 'could', 'have', 'bought', 'a', 'smaller', 'one', 'that', 'did', 'the', 'exact', 'same', 'thing', 'for', 'less', 'then', 'half', 'i', 'bought', 'it', 'for', 'the', 'video', 'chat', 'and', 'i', 'have', 'never', 'really', 'used', 'it', 'honestly i', 'i like', 'like it', 'it but', 'but at', 'at the', 'the same', 'same time', 'time i', 'i don', 'don t', 't i', 'i could', 'could have', 'have bought', 'bought a', 'a smaller', 'smaller one', 'one that', 'that did', 'did the', 'the exact', 'exact same', 'same thing', 'thing for', 'for less', 'less then', 'then half', 'half i', 'i bought', 'bought it', 'it for', 'for the', 'the video', 'video chat', 'chat and', 'and i', 'i have', 'have never', 'never really', 'really used', 'used it']
# ['it', 'is', 'very', 'slow', 'compared', 'to', 'the', 'echo', 'it is', 'is very', 'very slow', 'slow compared', 'compared to', 'to the', 'the echo']
# ['as', 'an', 'alexa', 'device', 'it', 'works', 'just', 'as', 'well', 'as', 'any', 'of', 'the', 'other', 'products', 'unfortunately', 'it', 'doesn', 't', 'go', 'up', 'from', 'there', 'the', 'ability', 'to', 'play', 'videos', 'is', 'very', 'limited', 'you', 'can', 'not', 'play', 'youtube', 'and', 'when', 'you', 'can', 'play', 'a', 'video', 'the', 'cropping', 'of', 'the', 'screen', 'makes', 'it', 'look', 'very', 'strange', 'there', 'is', 'quite', 'a', 'selection', 'of', 'clock', 'faces', 'and', 'you', 'can', 'control', 'what', 'is', 'displays', 'with', 'one', 'glaring', 'and', 'very', 'annoying', 'exception', 'you', 'can', 't', 'turn', 'off', 'the', '34', 'things', 'to', 'try', '34', 'screen', 'you', 'can', 'turn', 'off', 'the', 'screen', 'scroll', 'but', 'that', 'defeats', 'the', 'purpose', 'of', 'having', 'the', 'screen', 'i', 'don', 't', 'need', 'to', 'be', 'reminded', 'every', '5', 'seconds', 'what', 'things', 'i', 'can', 'do', 'with', 'alexa', 'i', 'don', 't', 'need', 'the', 'advertising', 'especially', 'at', 'the', 'cost', 'of', 'this', 'device', 'overall', 'its', 'an', 'expensive', 'alexa', 'device', 'with', 'a', 'screen', 'that', 's', 'not', 'very', 'useful', 'and', 'annoying', 'i', 'would', 'not', 'recommend', 'this', 'until', 'the', 'amazon', 'people', 'get', 'their', 'act', 'together', 'and', 'come', 'up', 'with', 'a', 'screen', 'that', 's', 'actually', 'useful', 'you can', 'the screen', 'alexa device', 'of the', 'turn off', 'off the', 'i don', 'don t', 't need', 'with a', 'a screen', 'screen that', 'that s', 'as an', 'an alexa', 'device it', 'it works', 'works just', 'just as', 'as well', 'well as', 'as any', 'any of', 'the other', 'other products', 'products unfortunately', 'unfortunately it', 'it doesn', 'doesn t', 't go', 'go up', 'up from', 'from there', 'there the', 'the ability', 'ability to', 'to play', 'play videos', 'videos is', 'is very', 'very limited', 'limited you', 'can not', 'not play', 'play youtube', 'youtube and', 'and when', 'when you', 'can play', 'play a', 'a video', 'video the', 'the cropping', 'cropping of', 'screen makes', 'makes it', 'it look', 'look very', 'very strange', 'strange there', 'there is', 'is quite', 'quite a', 'a selection', 'selection of', 'of clock', 'clock faces', 'faces and', 'and you', 'can control', 'control what', 'what is', 'is displays', 'displays with', 'with one', 'one glaring', 'glaring and', 'and very', 'very annoying', 'annoying exception', 'exception you', 'can t', 't turn', 'the 34', '34 things', 'things to', 'to try', 'try 34', '34 screen', 'screen you', 'can turn', 'screen scroll', 'scroll but', 'but that', 'that defeats', 'defeats the', 'the purpose', 'purpose of', 'of having', 'having the', 'screen i', 'need to', 'to be', 'be reminded', 'reminded every', 'every 5', '5 seconds', 'seconds what', 'what things', 'things i', 'i can', 'can do', 'do with', 'with alexa', 'alexa i', 'need the', 'the advertising', 'advertising especially', 'especially at', 'at the', 'the cost', 'cost of', 'of this', 'this device', 'device overall', 'overall its', 'its an', 'an expensive', 'expensive alexa', 'device with', 's not', 'not very', 'very useful', 'useful and', 'and annoying', 'annoying i', 'i would', 'would not', 'not recommend', 'recommend this', 'this until', 'until the', 'the amazon', 'amazon people', 'people get', 'get their', 'their act', 'act together', 'together and', 'and come', 'come up', 'up with', 's actually', 'actually useful']
# ['i', 'returnef', 'this', 'item', 'because', 'it', 'does', 'not', 'speak', 'spanish', 'i returnef', 'returnef this', 'this item', 'item because', 'because it', 'it does', 'does not', 'not speak', 'speak spanish']
# ['when', 'we', 'first', 'received', 'this', 'product', 'it', 'was', 'great', 'however', 'about', 'a', 'week', 'ago', 'the', 'device', 'served', 'up', 'a', 'video', 'advertisement', 'around', '10', '30pm', 'at', 'night', 'and', 'scared', 'myself', 'and', 'my', 'family', 'if', 'you', 'want', 'to', 'make', 'sure', 'you', 'are', 'protected', 'and', 'don', 't', 'allow', 'video', 'directly', 'in', 'your', 'home', 'the', 'spot', 'is', 'not', 'a', 'device', 'that', 'can', 'keep', 'you', 'safe', 'when we', 'we first', 'first received', 'received this', 'this product', 'product it', 'it was', 'was great', 'great however', 'however about', 'about a', 'a week', 'week ago', 'ago the', 'the device', 'device served', 'served up', 'up a', 'a video', 'video advertisement', 'advertisement around', 'around 10', '10 30pm', '30pm at', 'at night', 'night and', 'and scared', 'scared myself', 'myself and', 'and my', 'my family', 'family if', 'if you', 'you want', 'want to', 'to make', 'make sure', 'sure you', 'you are', 'are protected', 'protected and', 'and don', 'don t', 't allow', 'allow video', 'video directly', 'directly in', 'in your', 'your home', 'home the', 'the spot', 'spot is', 'is not', 'not a', 'a device', 'device that', 'that can', 'can keep', 'keep you', 'you safe']
# ['after', 'only', 'a', 'couple', 'of', 'days', 'alexa', 'did', 'not', 'answer', 'i', 'have', 'disconnected', 'and', 'will', 'see', 'if', 'it', 'does', 'any', 'better', 'after', 'reconnecting', 'after only', 'only a', 'a couple', 'couple of', 'of days', 'days alexa', 'alexa did', 'did not', 'not answer', 'answer i', 'i have', 'have disconnected', 'disconnected and', 'and will', 'will see', 'see if', 'if it', 'it does', 'does any', 'any better', 'better after', 'after reconnecting']
# ['i', 'wanted', 'to', 'use', 'it', 'as', 'a', 'clock', 'in', 'our', 'bedroom', 'but', 'the', 'font', 'is', 'too', 'small', 'to', 'see', 'from', 'any', 'distance', 'and', 'apparently', 'you', 'can', 't', 'change', 'it', 'i wanted', 'wanted to', 'to use', 'use it', 'it as', 'as a', 'a clock', 'clock in', 'in our', 'our bedroom', 'bedroom but', 'but the', 'the font', 'font is', 'is too', 'too small', 'small to', 'to see', 'see from', 'from any', 'any distance', 'distance and', 'and apparently', 'apparently you', 'you can', 'can t', 't change', 'change it']
# ['this', 'product', 'currently', 'has', 'two', 'related', 'software', 'flaws', 'that', 'make', 'it', 'completely', 'unusable', '1', 'there', 'is', 'a', '34', 'card', '34', 'on', 'the', 'homescreen', 'called', '34', 'things', 'to', 'try', '34', 'it', 's', 'an', 'ad', 'for', 'other', 'alexa', 'services', 'you', 'can', 'try', 'you', 'can', 'turn', 'off', 'all', 'the', 'other', 'homescreen', 'cards', 'but', 'not', 'this', 'one', '2', 'by', 'default', 'the', 'homescreen', 'cards', '34', 'cycle', '34', 'automatically', 'which', 'is', 'incredibly', 'annoying', 'there', 'is', 'a', 'setting', 'where', 'you', 'can', 'opt', 'to', 'have', 'the', 'cards', 'only', '34', 'cycle', 'once', '34', 'instead', 'of', '34', 'cycle', 'continuously', '34', 'but', 'critically', 'this', 'setting', 'does', 'not', 'work', 'my', 'unit', 'has', 'been', 'set', 'to', '34', 'cycle', 'once', '34', 'and', 'the', 'cards', 'still', 'continue', 'to', 'cycle', 'all', 'the', 'time', 'have', 'rebooted', 'the', 'device', 're', 'set', 'etc', 'etc', 'until', 'these', 'two', 'obvious', 'software', 'issues', 'are', 'fixed', 'in', 'my', 'opinion', 'the', 'product', 'is', 'useless', '34 cycle', 'you can', 'there is', 'is a', 'the homescreen', 'all the', 'homescreen cards', 'the cards', 'cycle once', 'once 34', 'this product', 'product currently', 'currently has', 'has two', 'two related', 'related software', 'software flaws', 'flaws that', 'that make', 'make it', 'it completely', 'completely unusable', 'unusable 1', '1 there', 'a 34', '34 card', 'card 34', '34 on', 'on the', 'homescreen called', 'called 34', '34 things', 'things to', 'to try', 'try 34', '34 it', 'it s', 's an', 'an ad', 'ad for', 'for other', 'other alexa', 'alexa services', 'services you', 'can try', 'try you', 'can turn', 'turn off', 'off all', 'the other', 'other homescreen', 'cards but', 'but not', 'not this', 'this one', 'one 2', '2 by', 'by default', 'default the', 'cards 34', 'cycle 34', '34 automatically', 'automatically which', 'which is', 'is incredibly', 'incredibly annoying', 'annoying there', 'a setting', 'setting where', 'where you', 'can opt', 'opt to', 'to have', 'have the', 'cards only', 'only 34', '34 instead', 'instead of', 'of 34', 'cycle continuously', 'continuously 34', '34 but', 'but critically', 'critically this', 'this setting', 'setting does', 'does not', 'not work', 'work my', 'my unit', 'unit has', 'has been', 'been set', 'set to', 'to 34', '34 and', 'and the', 'cards still', 'still continue', 'continue to', 'to cycle', 'cycle all', 'the time', 'time have', 'have rebooted', 'rebooted the', 'the device', 'device re', 're set', 'set etc', 'etc etc', 'etc until', 'until these', 'these two', 'two obvious', 'obvious software', 'software issues', 'issues are', 'are fixed', 'fixed in', 'in my', 'my opinion', 'opinion the', 'the product', 'product is', 'is useless']
# ['you', 'need', 'a', 'harvard', 'law', 'degree', 'to', 'operate', 'this', 'thing', 'it', 's', 'going', 'back', 'very', 'soon', 'you need', 'need a', 'a harvard', 'harvard law', 'law degree', 'degree to', 'to operate', 'operate this', 'this thing', 'thing it', 'it s', 's going', 'going back', 'back very', 'very soon']
# ['product', 'turns', 'on', 'randomly', 'and', 'sometimes', 'at', 'night', 'product turns', 'turns on', 'on randomly', 'randomly and', 'and sometimes', 'sometimes at', 'at night']
# ['i', 'would', 'love', 'this', 'but', 'there', 'is', 'no', 'way', 'to', 'stop', 'the', 'screen', 'from', 'constantly', 'scrolling', 'through', 'things', 'to', 'try', 'if', 'amazon', 'would', 'make', 'this', 'a', 'setting', 'i', 'would', 'change', 'my', 'review', 'to', '5', 'stars', 'i would', 'would love', 'love this', 'this but', 'but there', 'there is', 'is no', 'no way', 'way to', 'to stop', 'stop the', 'the screen', 'screen from', 'from constantly', 'constantly scrolling', 'scrolling through', 'through things', 'things to', 'to try', 'try if', 'if amazon', 'amazon would', 'would make', 'make this', 'this a', 'a setting', 'setting i', 'would change', 'change my', 'my review', 'review to', 'to 5', '5 stars']
# ['i', 'haven', 't', 'figured', 'out', 'how', 'to', 'make', 'or', 'receive', 'calls', 'device', 'tells', 'me', 'i', 'need', 'to', 'register', 'and', 'i', 'do', 'not', 'know', 'what', 'to', 'do', 'i haven', 'haven t', 't figured', 'figured out', 'out how', 'how to', 'to make', 'make or', 'or receive', 'receive calls', 'calls device', 'device tells', 'tells me', 'me i', 'i need', 'need to', 'to register', 'register and', 'and i', 'i do', 'do not', 'not know', 'know what', 'what to', 'to do']
# ...
#   'song',
#   'play',
#   '2',
#   'second',
#   'song',
#   'stop'],
#  ['absolutely',
#   'love',
#   'functionality',
#   'echo',
#   'however',
#   'two',
#   'month',
#   'use',
#   'scream',
#   'get',
#   'function',
#   'thinking',
#   'getting',
#   'rooms',
#   'want',
#   'spend',
#   'kind',
#   'money',
#   'works',
#   'properly',
#   'month'],
#  ['speaker',
#   'suck',
#   'want',
#   'change',
#   'bigger',
#   'one',
#   'target',
#   'let',
#   'change'],
#  ['use', 'week', 'get', 'boring'],
#  ['disappoint', 'sound'],
#  ['buy',
#   'echo',
#   'dot',
#   'amazon',
#   'sale',
#   'event',
#   'arrive',
#   'setup',
#   'le',
#   'straight',
#   'forward',
#   'google',
#   'things',
#   'able',
#   'especially',
#   'joke',
#   'easter',
#   'eggs',
#   'prove',
#   'entertain',
#   'one',
#   'evening',
#   'get',
#   'old',
#   'turn',
#   'feature',
#   'dot',
#   'compatible',
#   'smart',
#   'lighting',
#   'system',
#   'really',
#   'disappoint',
#   'one',
#   'thing',
#   'hope',
#   'device',
#   'read',
#   'web',
#   'page',
#   'dyslexia',
#   'make',
#   'reading',
#   'half',
#   'fast',
#   'average',
#   'person',
#   'really',
#   'like',
#   'listening',
#   'book',
#   'say',
#   'essay',
#   'dictate',
#   'quickly',
#   'jot',
#   'note',
#   'plus',
#   'list',
#   'driving',
#   'actually',
#   'imagine',
#   'getting',
#   'one',
#   'car',
#   'google',
#   'feature',
#   'android',
#   'using',
#   'years',
#   'significantly',
#   'capability',
#   'amazon',
#   'phone',
#   'read',
#   'entire',
#   'document',
#   'place',
#   'call',
#   'using',
#   'voice',
#   'surprisingly',
#   'new',
#   'feature',
#   'amazon',
#   'recently',
#   'able',
#   'roll',
#   'return',
#   'echo',
#   'dot',
#   'given',
#   'refund',
#   'imagine',
#   'product',
#   'much',
#   'better',
#   'five',
#   'years',
#   'time',
#   'think',
#   'better',
#   'talking'],
#  ['buy',
#   'husband',
#   'last',
#   'year',
#   'still',
#   'get',
#   'play',
#   'music',
#   'little',
#   'knowledge',
#   'mundane',
#   'things',
#   'end',
#   'buying',
#   'boom',
#   'box',
#   'finally',
#   'listen',
#   'cd',
#   'tune',
#   'music',
#   'none',
#   'play',
#   'stupid',
#   'thing',
#   'even',
#   'though',
#   'music',
#   'upload',
#   'ask',
#   'hear',
#   'music',
#   'name',
#   'play',
#   'entirely',
#   'different',
#   'library',
#   'give',
#   'star',
#   'great',
#   'idea',
#   'work',
#   'reasonable',
#   'way',
#   'complicate'],
#  ['two',
#   'get',
#   'time',
#   'one',
#   'break',
#   'month',
#   'unplug',
#   'one',
#   'room',
#   'plug',
#   'another',
#   'blue',
#   'ring',
#   'flash',
#   'rotate',
#   'orange',
#   'ring',
#   'way',
#   'set',
#   'unresponsive',
#   'keep',
#   'lighting',
#   'blue',
#   'ring',
#   'second',
#   'generation',
#   'echo',
#   'dot',
#   'couple',
#   'month',
#   'later',
#   'thing',
#   'happen',
#   'one',
#   'simply',
#   'move',
#   'one',
#   'room',
#   'another',
#   'apparently',
#   'like',
#   'move'],
#  ['really',
#   'use',
#   'news',
#   'weather',
#   'information',
#   'communicate',
#   'phone',
#   'make',
#   'call',
#   'echo',
#   'calendar',
#   'skill',
#   'need',
#   'echo'],
#  ['really',
#   'really',
#   'want',
#   'love',
#   'device',
#   'end',
#   'hate',
#   'like',
#   'petulant',
#   'defiant',
#   'five',
#   'year',
#   'old',
#   'whatever',
#   'plea',
#   'nothing',
#   'ask',
#   'part',
#   'issue',
#   'amazon',
#   'se',
#   'feel',
#   'dupe',
#   'read',
#   'time',
#   'new',
#   'things',
#   'add',
#   'reason',
#   'get',
#   'user',
#   'error',
#   'stupid',
#   'infuriate',
#   'problem',
#   'fact',
#   'buy',
#   'three',
#   'echo',
#   'dot',
#   'three',
#   'speaker',
#   'pair',
#   'three',
#   'different',
#   'location',
#   'house',
#   'one',
#   'new',
#   'feature',
#   'deliver',
#   'month',
#   'ago',
#   'do',
#   'thinking',
#   'speaker',
#   'make',
#   'call',
#   'cambridge',
#   'tell',
#   'echo',
#   'call',
#   'amazon',
#   'affirmed',
#   'desire',
#   'avoid',
#   'many',
#   'wire',
#   'possible',
#   'feel',
#   'overrun',
#   'times',
#   'buy',
#   'three',
#   'mini',
#   'cable',
#   'hook',
#   'speaker',
#   'run',
#   'music',
#   'throughout',
#   'house',
#   'course',
#   'speaker',
#   'plug',
#   'wall',
#   'b',
#   'c',
#   'three',
#   'run',
#   'time',
#   'another',
#   'example',
#   'ask',
#   'play',
#   'particular',
#   'song',
#   'particular',
#   'artist',
#   'play',
#   'one',
#   'day',
#   'ask',
#   'next',
#   'day',
#   'get',
#   'sorry',
#   'find',
#   'happen',
#   'constantly',
#   'also',
#   'notice',
#   'ask',
#   'play',
#   'damn',
#   'music',
#   'select',
#   'absolute',
#   'worst',
#   'song',
#   'artist',
#   'genre',
#   'notice',
#   'music',
#   'stream',
#   'amazon',
#   'music',
#   'account',
#   'original',
#   'artist',
#   'actually',
#   'stream',
#   'cover',
#   'group',
#   'complaint',
#   'wonder',
#   'might',
#   'experience',
#   'similar',
#   'problem'],
#  ['major',
#   'issue',
#   'privacy',
#   'concern',
#   'talking',
#   'home',
#   'office',
#   'respond',
#   'back',
#   'discuss',
#   'phone',
#   'middle',
#   'conversation',
#   'prompt'],
#  ['work',
#   'perfect',
#   'internet',
#   'connection',
#   'connection',
#   'go',
#   'work',
#   'cant',
#   'tell',
#   'time',
#   'asking',
#   'internet',
#   'interrupt',
#   'company',
#   'constantly',
#   'saying',
#   'quiet',
#   'stop',
#   'frustrate',
#   'add',
#   'light',
#   'function',
#   'worth',
#   'cost',
#   'imo',
#   'work',
#   'setting',
#   'timer',
#   'cooking',
#   'pretty',
#   'great',
#   'ask',
#   'much',
#   'time',
#   'left',
#   'timer',
#   'tell',
#   'set',
#   'multiple',
#   'timer',
#   'example',
#   'one',
#   'boiling',
#   'water',
#   'another',
#   'oven',
#   'say',
#   'keep',
#   'get',
#   'discount',
#   'amazon',
#   'prime',
#   'day',
#   'maybe',
#   'one',
#   'day',
#   'save',
#   'money',
#   'buy',
#   'light',
#   'p'],
#  ['seem', 'yell', 'get', 'ask', 'respond', 'better', 'deep', 'voice'],
#  ['capability',
#   'expect',
#   'additionally',
#   'problem',
#   'listening',
#   'command',
#   'give',
#   'thinking',
#   'buying',
#   'perhaps',
#   'google',
#   'product',
#   'thing',
#   'positive',
#   'daughter',
#   'enjoy'],
#  ['product',
#   'works',
#   'pretty',
#   'good',
#   'supplement',
#   'full',
#   'size',
#   'echo',
#   'problem',
#   '10',
#   'month',
#   'limited',
#   'use',
#   'reside',
#   'vacation',
#   'house',
#   'use',
#   'little',
#   'internal',
#   'speaker',
#   'unexpectedly',
#   'stop',
#   'working',
#   'connect',
#   'speaker',
#   'okay',
#   'work',
#   'using',
#   'internal',
#   'speaker',
#   'chat',
#   'amazon',
#   'customer',
#   'service',
#   'technical',
#   'service',
#   'determine',
#   'device',
#   'need',
#   'replace',
#   'warranty',
#   'way',
#   '90',
#   'days',
#   'offer',
#   'purchase',
#   'brand',
#   'new',
#   'one',
#   'great',
#   'discount',
#   'price',
#   'value',
#   'customer',
#   'note',
#   'sarcasm',
#   'problem',
#   'discount',
#   'price',
#   'offer',
#   'actually',
#   'spend',
#   'first',
#   'time',
#   'buy',
#   '10',
#   'month',
#   'ago',
#   'believe',
#   'offer',
#   'someone',
#   'purchase',
#   'echo',
#   'dot',
#   'prime',
#   'membership',
#   'lots',
#   'lots',
#   'amazon',
#   'order',
#   'justify',
#   'spending',
#   '40',
#   '50',
#   'every',
#   'year',
#   'replace',
#   'device',
#   'get',
#   '40',
#   'paperweight',
#   'guess',
#   'move',
#   'try',
#   'quality',
#   'apple',
#   'google',
#   'device'],
#  ['initial',
#   'impression',
#   'echo',
#   'dot',
#   'good',
#   'great',
#   'even',
#   'one',
#   'day',
#   'stops',
#   'function',
#   'week',
#   'prior',
#   'contact',
#   'tech',
#   'support',
#   'respond',
#   'email',
#   'contact',
#   'phone',
#   'chat',
#   'dot',
#   'longer',
#   'connect',
#   'amazon',
#   'device',
#   '3',
#   'hours',
#   'tech',
#   'support',
#   'believe',
#   'ever',
#   'say',
#   'fix',
#   'problem',
#   'another',
#   'pass',
#   'buck',
#   'le',
#   '4',
#   'times',
#   'amazon',
#   'department',
#   'verify',
#   'devices',
#   'fine',
#   'echo',
#   'team',
#   'nothing'],
#  ['device',
#   'bad',
#   'microphone',
#   'work',
#   'well',
#   'must',
#   'close',
#   'hear',
#   'option',
#   'playing',
#   'music',
#   'way',
#   'restore',
#   'device',
#   'recover',
#   'money',
#   'actually',
#   'pay',
#   'regret',
#   'buy'],
#  ['novelty',
#   'functional',
#   'keep',
#   'blue',
#   'tooth',
#   'devices',
#   'device',
#   'lack',
#   'many',
#   'core',
#   'ability',
#   'traffic',
#   'report',
#   'definition',
#   'search',
#   'capability'],
#  ['depend',
#   'want',
#   'going',
#   'one',
#   'fine',
#   'always',
#   'listen',
#   'good',
#   'ok',
#   'buy',
#   'dot',
#   'music',
#   'playing',
#   'one',
#   'already',
#   'echo',
#   'reading',
#   'devices',
#   'simply',
#   'say',
#   'one',
#   'device',
#   'play',
#   'music',
#   'clearly',
#   'explain',
#   'pay',
#   '15',
#   'month'],
#  ['well',
#   'buying',
#   'echo',
#   'dot',
#   'last',
#   'xmas',
#   'stop',
#   'working',
#   '30',
#   'day',
#   'return',
#   'window',
#   'return',
#   'item',
#   'figure',
#   'product',
#   'make',
#   'sell',
#   'amazon',
#   'year',
#   'warranty',
#   'least',
#   'wrong',
#   'nice',
#   'paperweight',
#   'customer',
#   'support',
#   'available',
#   'well',
#   'thanks',
#   'amazon',
#   'call',
#   'amazon',
#   'today',
#   'review',
#   'obviously',
#   'like',
#   'review',
#   'sent',
#   'steps',
#   'try',
#   'get',
#   'echo',
#   'dot',
#   'working',
#   'work',
#   'offer',
#   'return',
#   'replace',
#   'product',
#   'long',
#   'time',
#   'customer',
#   'expect',
#   'better',
#   'still',
#   'nice',
#   'paperweight',
#   'though'],
#  ['good',
#   'like',
#   'know',
#   'answer',
#   'simple',
#   'question',
#   'allow',
#   'change',
#   'name',
#   'want',
#   'like',
#   'dot'],
#  ['yet', 'get', 'sync', 'computer', 'spend', 'money', 'worthless', 'product'],
#  ['know',
#   'even',
#   'half',
#   'things',
#   'ask',
#   'make',
#   'whole',
#   'device',
#   'kinda',
#   'meaningless'],
#  ['breathing', 'machine', 'paralyze', 'neck', 'talk', 'loud', 'pick', 'use'],
#  ['constantly',
#   'plug',
#   'back',
#   'get',
#   'connect',
#   'internet',
#   'devices',
#   'connect',
#   'network',
#   'working',
#   'flawlessly'],
#  ['want',
#   'like',
#   'liking',
#   'keep',
#   'listening',
#   'half',
#   'time',
#   'get',
#   'right',
#   'idea',
#   'talking',
#   'may',
#   'times',
#   'tv',
#   'cause',
#   'wake',
#   'say',
#   'weird',
#   'crap',
#   'reason',
#   'buy',
#   'hub',
#   'still',
#   'issue',
#   'turning',
#   'ir',
#   'stuff',
#   'also',
#   'think',
#   'turn',
#   'ir',
#   'device',
#   'fix',
#   'obviously',
#   'works',
#   'well',
#   'new',
#   'wifi',
#   'enable',
#   'item'],
#  ['hard', 'time', 'getting', 'work', 'keep', 'getting', 'know', 'lot'],
#  ['security',
#   'order',
#   'one',
#   'also',
#   'regular',
#   'amazon',
#   'echo',
#   'found',
#   'online',
#   'review',
#   'absolutely',
#   'authentication',
#   'security',
#   'require',
#   'whatsoever',
#   'lots',
#   'story',
#   'online',
#   'think',
#   'neighbor',
#   'condo',
#   'apartment',
#   'connect',
#   'echo',
#   'device',
#   'authentication',
#   'approval',
#   'knowledge',
#   'amazon',
#   'know',
#   'better',
#   'provide',
#   'security',
#   'feature',
#   'configure',
#   'customize',
#   'pin',
#   'restrict',
#   'connection',
#   'really',
#   'want',
#   'give',
#   'echo',
#   'try',
#   'cancel',
#   'order',
#   'learning',
#   'amazon',
#   'total',
#   'disregard',
#   'security',
#   'disappoint',
#   'amazon',
#   'better'],
#  ['fault',
#   'get',
#   'respond',
#   'command',
#   'try',
#   'use',
#   'success',
#   'please',
#   'help'],
#  ['great',
#   'device',
#   'terrible',
#   'support',
#   'device',
#   'starting',
#   'problem',
#   'updating',
#   'firmware',
#   'amazon',
#   'solution',
#   'buy',
#   'new',
#   'one'],
#  ['like', 'suppose', 'turn', 'command'],
#  ['echo',
#   'great',
#   'hardware',
#   'product',
#   'stand',
#   'alone',
#   'product',
#   'give',
#   '5',
#   'star',
#   'review',
#   'pile',
#   'using',
#   '2',
#   'years',
#   'getting',
#   'better',
#   'learning',
#   'near',
#   'useless',
#   'know',
#   'specific',
#   'key',
#   'terms',
#   'example',
#   'play',
#   'country',
#   'station',
#   'play',
#   'country',
#   'song',
#   'release',
#   'current',
#   'song',
#   'playing',
#   'understand',
#   'score',
#   'washington',
#   'state',
#   'cougar',
#   'football',
#   'team',
#   'find',
#   'team',
#   'search',
#   'engine',
#   'tie',
#   'like',
#   'competitor',
#   'please',
#   'stop',
#   'buying',
#   'product',
#   'amazon',
#   'improve',
#   'ai',
#   'learning',
#   'ability',
#   'google',
#   'even',
#   'better',
#   'response',
#   'us',
#   'nw',
#   'zero',
#   'accent',
#   'kind'],
#  ['able', 'install', 'disappoint', 'need', 'money', 'back'],
#  ['works', 'like', 'use', 'sound', 'larger', 'sound'],
#  ['normally', 'respond', 'thing', 'use', 'timer', 'kitchen'],
#  ['minus', 'sign', 'echo', 'dot', 'working'],
#  ['get', 'work', 'instructions', 'sketchy', 'disappoint'],
#  ['works',
#   'well',
#   'original',
#   'big',
#   'knock',
#   'speaker',
#   'loud',
#   'sound',
#   'quality',
#   'poor',
#   'function',
#   'work',
#   'much'],
#  ['connect',
#   'google',
#   'product',
#   'might',
#   'well',
#   'throw',
#   'google',
#   'play',
#   'music',
#   'subscription',
#   'want',
#   'get',
#   'use',
#   'piece',
#   'garbage'],
#  ['play', 'music'],
#  ['understand', 'lots', 'question'],
#  ['live', 'cell', 'block', 'sound', 'ok', 'spend', 'money', 'get', 'large'],
#  ['frequently',
#   'use',
#   'echo',
#   'listen',
#   'music',
#   'news',
#   'problem',
#   'playing',
#   'able',
#   'hear',
#   'try',
#   'get',
#   'pause',
#   'music',
#   'change',
#   'stations',
#   'even',
#   'moderate',
#   'distance',
#   'playing',
#   'normal',
#   'volume',
#   'end',
#   'sitting',
#   'yelling',
#   'name',
#   'try',
#   'get',
#   'respond',
#   'ignore',
#   'like',
#   'teenager',
#   'house',
#   'end',
#   'walk',
#   'press',
#   'button',
#   'point',
#   'might',
#   'well',
#   'buy',
#   'radio'],
#  ['connect',
#   'wifi',
#   'troubleshoot',
#   'tip',
#   'worthless',
#   'buggy',
#   'unresponsive',
#   'customer',
#   'support',
#   'option',
#   'worthless',
#   'check',
#   'plug',
#   'crap',
#   'updating',
#   'wifi',
#   'network',
#   'absolute',
#   'disaster',
#   'worth',
#   'money',
#   'go',
#   'google'],
#  ['sound', 'quiet'],
#  ['excite',
#   'get',
#   'stay',
#   'online',
#   'anywhere',
#   'even',
#   'stay',
#   'power',
#   'randomly',
#   'turn',
#   'playing',
#   'music',
#   'disappoint',
#   'understatement',
#   'buy',
#   'use',
#   'classroom',
#   'thing',
#   'good',
#   'lining',
#   'trash',
#   'sad'],
#  ['gift', 'happy', 'buy', 'reset', 'almost', 'use', 'use', 'toy'],
#  ['hate', 'thing'],
#  ['connect', 'link', 'lightbulb'],
#  ['absolutely', 'horrible', 'never', 'know'],
#  ['work', 'public', 'wifi', 'useless', 'appear', 'nice', 'machine', 'though'],
#  ['difficulty',
#   'finding',
#   'amazon',
#   'song',
#   'title',
#   'quality',
#   'speaker',
#   'satisfy',
#   'return',
#   'today'],
#  ['google',
#   'search',
#   'connect',
#   'google',
#   'chrome',
#   'directly',
#   'use',
#   'netscape'],
#  ['listen', 'command', 'useless'],
#  ['sound', 'terrible'],
#  ['regret', 'buying', 'annoying', 'thing'],
#  ['trouble', 'buy', 'sometimes', 'works', 'times', 'worth', 'money'],
#  ['yet', 'find', 'purpose', 'whatever', 'better'],
#  ['pick',
#   'name',
#   'easily',
#   'seem',
#   'never',
#   'understand',
#   'scream',
#   'recommend',
#   'buying'],
#  ['8',
#   'days',
#   '90',
#   'day',
#   'warranty',
#   'echo',
#   'dot',
#   'brick',
#   'follow',
#   'fix',
#   'note',
#   'amazon',
#   'internet',
#   'avail',
#   'turn',
#   'connect',
#   'piece',
#   'junk'],
#  ['wont', 'listen', 'say', 'stop', 'alarm', 'buy', 'crap'],
#  ['go', 'loud', 'enough', 'hear'],
#  ['really',
#   'good',
#   'cant',
#   'answer',
#   'basic',
#   'question',
#   'like',
#   'weather',
#   'noon',
#   'today',
#   'tell',
#   'temperature',
#   'day',
#   'thing',
#   'good',
#   'use',
#   'play',
#   'music',
#   'voice',
#   'command',
#   'good',
#   'idea',
#   'product',
#   'practical',
#   'use',
#   'text',
#   'people',
#   'like',
#   'person',
#   'also',
#   'one',
#   'kind',
#   'waste',
#   'money'],
#  ['one',
#   'year',
#   'fix',
#   'replace',
#   'great',
#   'device',
#   'work',
#   'useless',
#   'fail',
#   'disappoint',
#   'buying',
#   'another',
#   'device'],
#  ['really',
#   'want',
#   'amazon',
#   'listening',
#   'conversation',
#   'amazon',
#   'owner',
#   'cia',
#   'put',
#   'house',
#   'might',
#   'even',
#   'camera',
#   'able',
#   'turn',
#   'want',
#   'fact',
#   'quit',
#   'dumb',
#   'burn'],
#  ['week',
#   'find',
#   'real',
#   'use',
#   'great',
#   'get',
#   'suggestion',
#   'make',
#   'use',
#   'feel',
#   'gimmick',
#   'nothing',
#   'eventually',
#   'people',
#   'loose',
#   'interest'],
#  ['going',
#   'keep',
#   'purely',
#   'alarm',
#   'pretty',
#   'terrible',
#   'pick',
#   'voice',
#   'time',
#   'yell',
#   'even',
#   'register',
#   'seem',
#   'well',
#   'make',
#   'responsive',
#   'regretful',
#   'purchase'],
#  ['quit', 'working', '6', 'week', 'permanent', 'red', 'ring'],
#  ['buy', 'different', 'one', 'rarely', 'connect', 'fail'],
#  ['really', 'care', 'dot'],
#  ['suck', 'say', 'insult', 'injury', 'buy', 'three'],
#  ['compatible', 'tv', 'contact', 'work', 'someone'],
#  ['get', 'work'],
#  ['know', 'lot'],
#  ['shame',
#   'try',
#   'one',
#   'friend',
#   'really',
#   'excite',
#   'get',
#   'mine',
#   'try',
#   'voice',
#   'training',
#   'hear',
#   '3',
#   '16',
#   'command',
#   'may',
#   'give',
#   'another',
#   'shot',
#   'already',
#   'pack',
#   'back',
#   'box',
#   'return',
#   'girlfriend',
#   'listen',
#   'free']]

# %%
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]

# %%
num_topics = 5

lda = LdaModel(corpus=corpus,  num_topics=num_topics, id2word=dictionary, passes=15) 
lda.save('test')

# %%
topics = lda.print_topics(num_words=8)
for topic in topics:
    print(topic)
# Out:
# (0, '0.016*"get" + 0.015*"echo" + 0.014*"ask" + 0.014*"work" + 0.013*"question" + 0.013*"buy" + 0.012*"one" + 0.012*"music"')
# (1, '0.027*"sound" + 0.017*"speaker" + 0.016*"work" + 0.014*"use" + 0.013*"music" + 0.012*"get" + 0.011*"good" + 0.011*"like"')
# (2, '0.017*"echo" + 0.017*"dot" + 0.014*"amazon" + 0.012*"device" + 0.011*"work" + 0.011*"get" + 0.008*"say" + 0.008*"time"')
# (3, '0.025*"echo" + 0.023*"amazon" + 0.018*"music" + 0.012*"dot" + 0.011*"play" + 0.011*"get" + 0.010*"use" + 0.009*"money"')
# (4, '0.014*"amazon" + 0.013*"product" + 0.012*"echo" + 0.011*"dot" + 0.011*"try" + 0.011*"34" + 0.010*"connect" + 0.009*"get"')
